# %% [markdown]
# ## Varios mapeos

# %%
using PyPlot
using TaylorSeries

# %%
push!(LOAD_PATH,"/home/evelyn/Documentos/Tesis/Programas/IPM")
# Out:
# 3-element Array{String,1}:
#  "/usr/local/share/julia/site/v0.5"
#  "/usr/share/julia/site/v0.5"
#  "/home/evelyn/Documentos/Tesis/Programas/IPM"

# %%
using ParametrizacionMetodo

# %%
function Rotor(x,y,a)
   
    x_n = x+y
    y_n = y+a*x_n*(x_n-1.)*e^(-x_n)

    return [x_n,y_n]
end
# Out:
# Rotor (generic function with 1 method)

# %%
b=parse(BigFloat,"3.4")
g(x,y)=Rotor(x,y,b)
f(x,y)=Rotor(x,y,3.4)
# Out:
# f (generic function with 1 method)

# %%
#tiempo
#t1=[-big(5.),big(5.)]
t2=[-big(5.),big(5.)]
#Calculamos variedad inestable del mapeo de Jung
#PolinomioE,PLE = Estable(g, 20, [big(1.),big(0.)], t1, 0.125)
PolinomioI,PLI = Inestable(g, 20, [big(1.),big(0.)],t2, 0.125)
PolinomioI2,PLI2 = Inestable(g, 25, [big(1.),big(0.)],t2, 0.125)
PolinomioI3,PLI3 = Inestable(g, 30, [big(1.),big(0.)],t2, 0.125)
#V=Evaluar(t1,0.025,PolinomioE[1],PolinomioE[2])
B=Evaluar(t2,0.025,PolinomioI[1],PolinomioI[2])
B2=Evaluar(t2,0.025,PolinomioI[1],PolinomioI[2])
B3=Evaluar(t2,0.025,PolinomioI[1],PolinomioI[2])
# Out:
# ([4.28926,4.27804,4.26677,4.25546,4.24411,4.23272,4.22128,4.20979,4.19827,4.1867  …  0.443167,0.480864,0.51916,0.558055,0.597547,0.637634,0.678316,0.71959,0.761453,0.803905],[-1.91513,-1.91024,-1.90531,-1.90035,-1.89535,-1.89031,-1.88524,-1.88013,-1.87498,-1.8698  …  -0.711473,-0.754672,-0.798449,-0.842805,-0.887736,-0.933242,-0.979321,-1.02597,-1.07319,-1.12097])

# %%
figure(1)
#pygui(true)
plot(B[1],B[2],color="r",label="Inestable 20")
plot(B2[1],B2[2],color="b",label="Inestable 25")
plot(B3[1],B3[2],color="g",label="Inestable 30")
#plot(V[1],V[2],color="b",label="estable")
xlim(-1,1.2)
ylim(-1,1)
#title("Mapeo exponencial  ,BigFloat, orden 20")
grid("on")
legend(loc="upper right",fancybox="true" )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c00fb8110>)
# PyObject <matplotlib.legend.Legend object at 0x7f2c00ab0f50>

# %%
t=[-big(10.),big(10.)]
#E1=CalculoError(g, PolinomioE, PLE,t,0.025)
E1=CalculoError(g, PolinomioI, PLI,t,0.025)
E2=CalculoError(g, PolinomioI2, PLI2,t,0.025)
E3=CalculoError(g, PolinomioI3, PLI3,t,0.025)
# Out:
# 2-element Array{Array{BigFloat,1},1}:

# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c006ab2d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2bfff6b5d0>

# %%
#X,Y=Convergencia(PolinomioE[1],PolinomioE[2])
z1,W1=Convergencia(PolinomioI[1],PolinomioI[2])
z2,W2=Convergencia(PolinomioI2[1],PolinomioI2[2])
z3,W3=Convergencia(PolinomioI3[1],PolinomioI3[2])
#plot(X,marker=".",label=L"P(x) Estable")
#plot(Y,marker=".",label=L"P(y) Estable")
plot(z1,marker="*",label=L"P(x) Inestable")
plot(W1,marker="*",label=L"P(y) Inestable")
#plot(z2,marker="*",label=L"P(x) Inestable")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c0005fd10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2bffdf0b50>

# %%
#a=3.4
t=[-5.,5.]
Polinomio1G, E1G = Estable(f, 25, [1.,0.], t, 0.125)
#Polinomio2G, E2G = Inestable(f, 25, [1.,0.], t, 0.125)
#V=Evaluar(t,0.025,Polinomio2G[1],Polinomio2G[2])
B=Evaluar(t,0.025,Polinomio1G[1],Polinomio1G[2])
# Out:
# ([3.09861,3.0898,3.08096,3.07211,3.06324,3.05435,3.04544,3.03651,3.02757,3.0186  …  -0.731922,-0.734955,-0.73788,-0.740696,-0.743403,-0.745999,-0.748485,-0.750858,-0.753119,-0.755267],[2.30882,2.30568,2.30249,2.29926,2.29598,2.29265,2.28928,2.28586,2.28239,2.27888  …  7.97588,8.05677,8.13539,8.21169,8.28558,8.35699,8.42585,8.49209,8.55563,8.61641])

# %%
figure(4)
#pygui(true)
#plot(V[1],V[2],label="Inestable")
plot(B[1],B[2],label="Estable")
xlim(-1.,1.3)
ylim(-1.,1.)
grid("on")
title("Mapeo exponencial ,Float64, orden 25")
legend(loc="upper right",fancybox="true" )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c056c6ad0>)
# PyObject <matplotlib.legend.Legend object at 0x7f2c050d6490>

# %%
t=[-5.,5.]
E1=CalculoError(f, Polinomio1G, E1G,t,0.025)
#E2=CalculoError(f, Polinomio2G, E2G,t,0.025)
# Out:
# 2-element Array{Array{Float64,1},1}:
#  [-5.0,-4.975,-4.95,-4.925,-4.9,-4.875,-4.85,-4.825,-4.8,-4.775  …  4.775,4.8,4.825,4.85,4.875,4.9,4.925,4.95,4.975,5.0]
#  [3.35518e-7,2.97014e-7,2.62776e-7,2.32347e-7,2.0532e-7,1.81329e-7,1.60044e-7,1.41171e-7,1.24448e-7,1.09637e-7  …  3.78682e-8,4.24357e-8,4.75105e-8,5.31438e-8,5.93915e-8,6.63142e-8,7.3978e-8,8.24545e-8,9.18215e-8,1.02163e-7]

# %%
figure(5)
plot(E1[1],log10(E1[2]),marker= "None", label="Estable")
#plot(E2[1],log10(E2[2]),marker= "None", label="Inestable")
xlabel("Parámetro t")
ylabel(L"log10($|| E||_{\infty})$")
title("Error")
grid("on")
legend(loc="upper right",fancybox="true" )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c0508e450>)
# PyObject <matplotlib.legend.Legend object at 0x7f2c04b0c7d0>

# %%
X,Y=Convergencia(Polinomio1G[1],Polinomio1G[2])
#z,W=Convergencia(PolinomioI[1],PolinomioI[2])
plot(X,marker=".",label=L"P(x) Estable")
plot(Y,marker=".",label=L"P(y) Estable")
#plot(z,marker="*",label=L"P(x) Inestable")
#plot(W,marker="*",label=L"P(y) Inestable")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c0499e210>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2c04919390>

# %%
X,Y=Convergencia3(Polinomio1G[1],Polinomio1G[2])
#z,W=Convergencia(PolinomioI[1],PolinomioI[2])
plot(X,marker=".",label=L"P(x) Estable")
plot(Y,marker=".",label=L"P(y) Estable")
#plot(z,marker="*",label=L"P(x) Inestable")
#plot(W,marker="*",label=L"P(y) Inestable")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c048e63d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2c00b77910>

# %%
function evaluar(Tiempo, paso,A,B)
    ValX=Float64[]
    
    ValY=Float64[]

    for t = Tiempo[1]:paso:Tiempo[2]
        
        x = mod(evaluate(A,t),1)
        y = mod(evaluate(B,t),1)
        
        push!(ValX,x)
        push!(ValY,y)
        
    end
    return ValX,ValY
    
end
# Out:
# WARNING: Method definition evaluar(Any, Any, Any, Any) in module Main at In[21]:2 overwritten at In[24]:2.
# evaluar (generic function with 1 method)

# %%
function Arnold(x,y)
    x_n = mod(2*x+y,1)
    y_n = mod(x+y,1)
    return [x_n,y_n]
end
# Out:
# Arnold (generic function with 2 methods)

# %%
ta=[-3.,3.]
PolArnold,ErrA=Inestable(Arnold,25,[0.,0.],ta,0.125)
AA=evaluar(ta,0.025,PolArnold[1],PolArnold[2])
# Out:
# ([0.422807,0.43595,0.449093,0.462236,0.47538,0.488523,0.501666,0.51481,0.527953,0.541096  …  0.458904,0.472047,0.48519,0.498334,0.511477,0.52462,0.537764,0.550907,0.56405,0.577193],[0.551952,0.530686,0.50942,0.488154,0.466887,0.445621,0.424355,0.403089,0.381822,0.360556  …  0.639444,0.618178,0.596911,0.575645,0.554379,0.533113,0.511846,0.49058,0.469314,0.448048])

# %%
figure(6)
plot(AA[1],AA[2],color="r",label="Inestable")
xlim(0.,1.)
ylim(0.,1.)
grid("on")
legend(loc="upper right",fancybox="true" )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c00f80f50>)
# PyObject <matplotlib.legend.Legend object at 0x7f2c04e5ced0>

# %%
t=[-3.,3.]
E1=CalculoError(Arnold, PolArnold, ErrA,t,0.025)
# Out:
# 2-element Array{Array{Float64,1},1}:
#  [-3.0,-2.975,-2.95,-2.925,-2.9,-2.875,-2.85,-2.825,-2.8,-2.775  …  2.775,2.8,2.825,2.85,2.875,2.9,2.925,2.95,2.975,3.0]
#  [4.16334e-16,4.12864e-16,4.09395e-16,4.05925e-16,4.02456e-16,3.98986e-16,3.95517e-16,3.92048e-16,3.88578e-16,3.85109e-16  …  3.85109e-16,3.88578e-16,3.92048e-16,3.95517e-16,3.98986e-16,4.02456e-16,4.05925e-16,4.09395e-16,4.12864e-16,4.16334e-16]

# %%
figure(7)
plot(E1[1],log10(E1[2]),marker= "None", label="Inestable")
xlabel("Parámetro t")
ylabel(L"log10($|| E||_{\infty})$")
title("Error")
grid("on")
legend(loc="upper right",fancybox="true" )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c056fce50>)
# PyObject <matplotlib.legend.Legend object at 0x7f2c04a552d0>

# %%
X,Y=Convergencia3(PolArnold[1],PolArnold[2])
plot(X,marker=".",label=L"P(x) Estable")
plot(Y,marker=".",label=L"P(y) Estable")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2c00cb3650>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2c00c45a90>
