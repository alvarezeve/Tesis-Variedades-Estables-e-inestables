# %%
using PyPlot

# %%
x=[1,2,3,4,5,6,7]
y=[2,4,1,5,6,7,8]
# Out:
# 7-element Array{Int64,1}:
#  2
#  4
#  1
#  5
#  6
#  7
#  8

# %%
p = plot(x,y, )

xlabel("X")
ylabel("Y")
title("Your Title Goes Here")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f40ed004450>)

# %%
p = scatter(x,y,color="purple",marker="o",label="Second")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f40ea97b0d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f40ea8f6750>

# %%
cs = [colors[i//length(x)] for i =(len(y)*len(x))]
# Out:
# LoadError: UndefVarError: len not defined
# while loading In[11], in expression starting on line 1
#
#  in anonymous at no file

# %%
annotate(L"$\int x = \frac{x^2}{2} + C$",
    xy=[1;0],
    xycoords="axes fraction",
    xytext=[-10,10],
    textcoords="offset points",
    fontsize=30.0,
    ha="right",
    va="bottom")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f92065a7190>)
# PyObject <matplotlib.text.Annotation object at 0x7f920655bdd0>

# %%
K = [0.06, 0.971635, 1.2, 2]
n = 1000

plt.figure()
for k in K:
    for theta_i in numpy.linspace(0,2*math.pi, 20):
     for p_i in numpy.linspace(0,2*math.pi,20):
            t,p = iterarMap(MapEstandar,theta_i,p_i,n, k)
            plt.plot (t,p,'.', markersize=3)
    plt.show()
