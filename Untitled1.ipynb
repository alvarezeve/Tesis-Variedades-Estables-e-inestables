# %%
using Plots

# %%
y = rand(100)
plot(0:10:100,rand(11,4),lab="lines",w=3,palette=:grays,fill=(0.5,:auto))
scatter!(y,z=abs(y - 0.5),m=(10,:heat),lab="grad")
# Out:
# INFO: Installing matplotlib via the Conda matplotlib package...
# Fetching package metadata .......
# Solving package specifications: ..........
#
# Package plan for installation in environment /home/evelyn/.julia/v0.5/Conda/deps/usr:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     expat-2.1.0                |                0         365 KB
#     icu-54.1                   |                0        11.3 MB
#     jpeg-8d                    |                2         806 KB
#     libffi-3.2.1               |                1          38 KB
#     libgcc-5.2.0               |                0         1.1 MB
#     libiconv-1.14              |                0         2.0 MB
#     libxcb-1.12                |                1         1.5 MB
#     pixman-0.34.0              |                0         3.8 MB
#     dbus-1.10.10               |                0         2.4 MB
#     libpng-1.6.22              |                0         214 KB
#     libxml2-2.9.4              |                0         3.7 MB
#     pcre-8.39                  |                1         656 KB
#     freetype-2.5.5             |                1         2.5 MB
#     glib-2.50.2                |                0         7.0 MB
#     pyparsing-2.1.4            |           py27_0          70 KB
#     pytz-2016.10               |           py27_0         205 KB
#     sip-4.18                   |           py27_0         264 KB
#     six-1.10.0                 |           py27_0          16 KB
#     cycler-0.10.0              |           py27_0          11 KB
#     fontconfig-2.12.1          |                0         431 KB
#     gstreamer-1.8.0            |                0         2.6 MB
#     python-dateutil-2.6.0      |           py27_0         232 KB
#     cairo-1.14.6               |                0         606 KB
#     gst-plugins-base-1.8.0     |                0         3.1 MB
#     pycairo-1.10.0             |           py27_0          81 KB
#     qt-5.6.2                   |                2        44.2 MB
#     pyqt-5.6.0                 |           py27_1         5.3 MB
#     matplotlib-1.5.3           |      np111py27_1         8.2 MB
#     ------------------------------------------------------------
#                                            Total:       102.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     cairo:            1.14.6-0
#     cycler:           0.10.0-py27_0
#     dbus:             1.10.10-0
#     expat:            2.1.0-0
#     fontconfig:       2.12.1-0
#     freetype:         2.5.5-1
#     glib:             2.50.2-0
#     gst-plugins-base: 1.8.0-0
#     gstreamer:        1.8.0-0
#     icu:              54.1-0
#     jpeg:             8d-2
#     libffi:           3.2.1-1
#     libgcc:           5.2.0-0
#     libiconv:         1.14-0
#     libpng:           1.6.22-0
#     libxcb:           1.12-1
#     libxml2:          2.9.4-0
#     matplotlib:       1.5.3-np111py27_1
#     pcre:             8.39-1
#     pixman:           0.34.0-0
#     pycairo:          1.10.0-py27_0
#     pyparsing:        2.1.4-py27_0
#     pyqt:             5.6.0-py27_1
#     python-dateutil:  2.6.0-py27_0
#     pytz:             2016.10-py27_0
#     qt:               5.6.2-2
#     sip:              4.18-py27_0
#     six:              1.10.0-py27_0
#
# Fetching packages ...
# expat-2.1.0-0. 100% |###############################| Time: 0:00:00   1.41 MB/s
# icu-54.1-0.tar 100% |###############################| Time: 0:00:09   1.25 MB/s
# jpeg-8d-2.tar. 100% |###############################| Time: 0:00:00   1.42 MB/s
# libffi-3.2.1-1 100% |###############################| Time: 0:00:00 318.66 kB/s
# libgcc-5.2.0-0 100% |###############################| Time: 0:00:00   1.45 MB/s
# libiconv-1.14- 100% |###############################| Time: 0:00:01   1.42 MB/s
# libxcb-1.12-1. 100% |###############################| Time: 0:00:01   1.43 MB/s
# pixman-0.34.0- 100% |###############################| Time: 0:00:02   1.40 MB/s
# dbus-1.10.10-0 100% |###############################| Time: 0:00:01   1.41 MB/s
# libpng-1.6.22- 100% |###############################| Time: 0:00:00   1.22 MB/s
# libxml2-2.9.4- 100% |###############################| Time: 0:00:03 973.70 kB/s
# pcre-8.39-1.ta 100% |###############################| Time: 0:00:00   1.07 MB/s
# freetype-2.5.5 100% |###############################| Time: 0:00:02   1.28 MB/s
# glib-2.50.2-0. 100% |###############################| Time: 0:00:06   1.21 MB/s
# pyparsing-2.1. 100% |###############################| Time: 0:00:00 707.67 kB/s
# pytz-2016.10-p 100% |###############################| Time: 0:00:00   1.17 MB/s
# sip-4.18-py27_ 100% |###############################| Time: 0:00:00   1.43 MB/s
# six-1.10.0-py2 100% |###############################| Time: 0:00:00 383.62 kB/s
# cycler-0.10.0- 100% |###############################| Time: 0:00:00   3.48 MB/s
# fontconfig-2.1 100% |###############################| Time: 0:00:00   1.40 MB/s
# gstreamer-1.8. 100% |###############################| Time: 0:00:01   1.42 MB/s
# python-dateuti 100% |###############################| Time: 0:00:00   1.33 MB/s
# cairo-1.14.6-0 100% |###############################| Time: 0:00:00   1.46 MB/s
# gst-plugins-ba 100% |###############################| Time: 0:00:02   1.41 MB/s
# pycairo-1.10.0 100% |###############################| Time: 0:00:00 699.47 kB/s
# qt-5.6.2-2.tar 100% |###############################| Time: 0:00:34   1.36 MB/s
# pyqt-5.6.0-py2 100% |###############################| Time: 0:00:03   1.40 MB/s
# matplotlib-1.5 100% |###############################| Time: 0:00:06   1.37 MB/s
# Extracting packages ...
# [      COMPLETE      ]|##################################################| 100%
# Linking packages ...
# [      COMPLETE      ]|##################################################| 100%
# dbus post-link :: /etc/machine-id not found ..
# dbus post-link :: .. using /proc/sys/kernel/random/boot_id
# /home/evelyn/.julia/v0.5/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <img src="data:image/png;base64,..." />
# /home/evelyn/.julia/v0.5/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
